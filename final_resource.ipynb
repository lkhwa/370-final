# %%
import helper_functions as hf

df = hf.get_final_df()
df
# Out:
#                   business_id        city state  stars  \
# 0      EsMcGiZaQuG1OOvL9iUFug     Wexford    PA    5.0
# 1      lHYiCS-y8AFjUitv6MGpxg     Toronto    ON    4.0
# 2      lHYiCS-y8AFjUitv6MGpxg     Toronto    ON    4.0
# 3      lHYiCS-y8AFjUitv6MGpxg     Toronto    ON    4.0
# 4      lHYiCS-y8AFjUitv6MGpxg     Toronto    ON    4.0
# 5      lHYiCS-y8AFjUitv6MGpxg     Toronto    ON    4.0
# 6      lHYiCS-y8AFjUitv6MGpxg     Toronto    ON    4.0
# 7      lHYiCS-y8AFjUitv6MGpxg     Toronto    ON    4.0
# 8      lHYiCS-y8AFjUitv6MGpxg     Toronto    ON    4.0
# 9      AtdXq_gu9NTE5rx4ct_dGg     Toronto    ON    4.0
# 10     AtdXq_gu9NTE5rx4ct_dGg     Toronto    ON    4.0
# 11     AtdXq_gu9NTE5rx4ct_dGg     Toronto    ON    4.0
# 12     gAy4LYpsScrj8POnCW6btQ   Fort Mill    SC    3.5
# 13     FXHfcFVEfI1vVngW2gVOpw     Toronto    ON    4.0
# 14     FXHfcFVEfI1vVngW2gVOpw     Toronto    ON    4.0
# 15     FXHfcFVEfI1vVngW2gVOpw     Toronto    ON    4.0
# ...

# %%
testing_df = df.copy()
testing_df
# Out:
#                   business_id        city state  stars  \
# 0      EsMcGiZaQuG1OOvL9iUFug     Wexford    PA    5.0
# 1      lHYiCS-y8AFjUitv6MGpxg     Toronto    ON    4.0
# 2      lHYiCS-y8AFjUitv6MGpxg     Toronto    ON    4.0
# 3      lHYiCS-y8AFjUitv6MGpxg     Toronto    ON    4.0
# 4      lHYiCS-y8AFjUitv6MGpxg     Toronto    ON    4.0
# 5      lHYiCS-y8AFjUitv6MGpxg     Toronto    ON    4.0
# 6      lHYiCS-y8AFjUitv6MGpxg     Toronto    ON    4.0
# 7      lHYiCS-y8AFjUitv6MGpxg     Toronto    ON    4.0
# 8      lHYiCS-y8AFjUitv6MGpxg     Toronto    ON    4.0
# 9      AtdXq_gu9NTE5rx4ct_dGg     Toronto    ON    4.0
# 10     AtdXq_gu9NTE5rx4ct_dGg     Toronto    ON    4.0
# 11     AtdXq_gu9NTE5rx4ct_dGg     Toronto    ON    4.0
# 12     gAy4LYpsScrj8POnCW6btQ   Fort Mill    SC    3.5
# 13     FXHfcFVEfI1vVngW2gVOpw     Toronto    ON    4.0
# 14     FXHfcFVEfI1vVngW2gVOpw     Toronto    ON    4.0
# 15     FXHfcFVEfI1vVngW2gVOpw     Toronto    ON    4.0
# ...

# %%
hf.aggregate_df(testing_df)
# Out:
#                  business_id  stars  num_positive_words  num_negative_words  \
# 0     -0BxAGlIk5DJAGVkpqBXxg    3.0                  26                  14
# 1     -0T0jfPnuBRdpNTXpOQZcA    2.0                   5                   1
# 2     -0aIra_B6iALlfqAriBSYA    4.5                   8                   1
# 3     -2Arz8twKJmxHMS3Sv-TeA    3.5                   0                   0
# 4     -2uYjztVuVZpkTNAC38zdg    3.5                   1                   0
# 5     -3AVh1GtLRc-HOwORLuzaQ    3.0                   5                   4
# 6     -4eA7Um2eiOKsGLmcXNx_w    4.0                  17                   3
# 7     -6CGECRbeyTCeyU4oHeXHQ    2.5                   2                   3
# 8     -6NrhIFET7iWi4d5538fiA    4.0                   3                   1
# 9     -76didnxGiiMO80BjSpYsQ    3.0                  29                  11
# 10    -7PuYohz9dR80iGfVR_kLA    4.0                   4                   0
# ...

# %%
high_df = testing_df[['business_id', 'stars', 'text']].loc[(testing_df['stars'] >= 4.0)]
low_df = testing_df[['business_id', 'stars', 'text']].loc[(testing_df['stars'] <= 2.0)]

# %%
top_ten_high = hf.top_ten(high_df)
top_ten_high
# Out:
# [('great', 9180),
#  ('coffee', 7416),
#  ('place', 6192),
#  ('good', 5667),
#  ('food', 4547),
#  ('love', 4055),
#  ('best', 4045),
#  ('service', 3989),
#  ('get', 3058),
#  ('amazing', 2798)]

# %%
top_ten_low = hf.top_ten(low_df)
top_ten_low
# Out:
# [('coffee', 209),
#  ('service', 173),
#  ('starbucks', 129),
#  ('drive', 126),
#  ('get', 118),
#  ('thru', 96),
#  ('location', 94),
#  ('good', 94),
#  ('go', 82),
#  ('great', 80)]

# %%
top_50_high = hf.top_fifty(high_df)
top_50_high
# Out:
# [('great', 9180),
#  ('coffee', 7416),
#  ('place', 6192),
#  ('good', 5667),
#  ('food', 4547),
#  ('love', 4055),
#  ('best', 4045),
#  ('service', 3989),
#  ('get', 3058),
#  ('amazing', 2798),
#  ('delicious', 2781),
#  ('try', 2767),
#  ('tea', 2720),
#  ('friendly', 2410),
#  ('breakfast', 2209),
#  ('nice', 2063),
#  ('awesome', 2060),
#  ('staff', 1976),
#  ('like', 1801),
#  ('latte', 1685),
#  ('time', 1677),
#  ('go', 1656),
#  ('free', 1638),
#  ('one', 1475),
#  ('always', 1441),
#  ('chocolate', 1430),
#  ('back', 1410),
#  ('really', 1400),
#  ('milk', 1253),
#  ('new', 1249),
#  ('fresh', 1221),
#  ('iced', 1183),
#  ('day', 1167),
#  ('spot', 1132),
#  ('atmosphere', 1123),
#  ('come', 1117),
#  ('excellent', 1105),
#  ('yummy', 1104),
#  ('ever', 1082),
#  ('little', 1059),
#  ('boba', 1055),
#  ('menu', 1045),
#  ('order', 1021),
#  ('drinks', 1020),
#  ('favorite', 1014),
#  ('super', 997),
#  ('drink', 990),
#  ('cream', 989),
#  ('open', 973),
#  ('ice', 971)]

# %%
top_100_high = hf.top_hundred(high_df)
top_100_high
# Out:
# [('great', 9180),
#  ('coffee', 7416),
#  ('place', 6192),
#  ('good', 5667),
#  ('food', 4547),
#  ('love', 4055),
#  ('best', 4045),
#  ('service', 3989),
#  ('get', 3058),
#  ('amazing', 2798),
#  ('delicious', 2781),
#  ('try', 2767),
#  ('tea', 2720),
#  ('friendly', 2410),
#  ('breakfast', 2209),
#  ('nice', 2063),
#  ('awesome', 2060),
#  ('staff', 1976),
#  ('like', 1801),
#  ('latte', 1685),
#  ('time', 1677),
#  ('go', 1656),
#  ('free', 1638),
#  ('one', 1475),
#  ('always', 1441),
#  ('chocolate', 1430),
#  ('back', 1410),
#  ('really', 1400),
#  ('milk', 1253),
#  ('new', 1249),
#  ('fresh', 1221),
#  ('iced', 1183),
#  ('day', 1167),
#  ('spot', 1132),
#  ('atmosphere', 1123),
#  ('come', 1117),
#  ('excellent', 1105),
#  ('yummy', 1104),
#  ('ever', 1082),
#  ('little', 1059),
#  ('boba', 1055),
#  ('menu', 1045),
#  ('order', 1021),
#  ('drinks', 1020),
#  ('favorite', 1014),
#  ('super', 997),
#  ('drink', 990),
#  ('cream', 989),
#  ('open', 973),
#  ('ice', 971),
# ...

# %%
top_20_high = hf.top_twenty(high_df)
top_20_high
# Out:
# [('great', 9180),
#  ('coffee', 7416),
#  ('place', 6192),
#  ('good', 5667),
#  ('food', 4547),
#  ('love', 4055),
#  ('best', 4045),
#  ('service', 3989),
#  ('get', 3058),
#  ('amazing', 2798),
#  ('delicious', 2781),
#  ('try', 2767),
#  ('tea', 2720),
#  ('friendly', 2410),
#  ('breakfast', 2209),
#  ('nice', 2063),
#  ('awesome', 2060),
#  ('staff', 1976),
#  ('like', 1801),
#  ('latte', 1685)]

# %%
top_50_low = hf.top_fifty(low_df)
top_50_low
# Out:
# [('coffee', 209),
#  ('service', 173),
#  ('starbucks', 129),
#  ('drive', 126),
#  ('get', 118),
#  ('thru', 96),
#  ('location', 94),
#  ('good', 94),
#  ('go', 82),
#  ('great', 80),
#  ('always', 80),
#  ('place', 73),
#  ('order', 64),
#  ('one', 63),
#  ('free', 61),
#  ('slow', 61),
#  ('long', 58),
#  ('staff', 57),
#  ('love', 54),
#  ('donuts', 53),
#  ('time', 53),
#  ('food', 53),
#  ('tea', 49),
#  ('nice', 49),
#  ('line', 48),
#  ('friendly', 48),
#  ('customer', 46),
#  ('fast', 45),
#  ('ever', 45),
#  ('open', 44),
#  ('smoothie', 43),
#  ('like', 42),
#  ('day', 41),
#  ('today', 38),
#  ('morning', 38),
#  ('card', 38),
#  ('dunkin', 37),
#  ('minutes', 37),
#  ('drinks', 36),
#  ('inside', 36),
#  ('best', 35),
#  ('iced', 34),
#  ('come', 33),
#  ('new', 33),
#  ('really', 33),
#  ('got', 31),
#  ('drink', 31),
#  ('better', 31),
#  ('wait', 30),
#  ('super', 29)]

# %%
top_100_low = hf.top_hundred(low_df)
top_100_low
# Out:
# [('coffee', 209),
#  ('service', 173),
#  ('starbucks', 129),
#  ('drive', 126),
#  ('get', 118),
#  ('thru', 96),
#  ('location', 94),
#  ('good', 94),
#  ('go', 82),
#  ('great', 80),
#  ('always', 80),
#  ('place', 73),
#  ('order', 64),
#  ('one', 63),
#  ('free', 61),
#  ('slow', 61),
#  ('long', 58),
#  ('staff', 57),
#  ('love', 54),
#  ('donuts', 53),
#  ('time', 53),
#  ('food', 53),
#  ('tea', 49),
#  ('nice', 49),
#  ('line', 48),
#  ('friendly', 48),
#  ('customer', 46),
#  ('fast', 45),
#  ('ever', 45),
#  ('open', 44),
#  ('smoothie', 43),
#  ('like', 42),
#  ('day', 41),
#  ('today', 38),
#  ('morning', 38),
#  ('card', 38),
#  ('dunkin', 37),
#  ('minutes', 37),
#  ('drinks', 36),
#  ('inside', 36),
#  ('best', 35),
#  ('iced', 34),
#  ('come', 33),
#  ('new', 33),
#  ('really', 33),
#  ('got', 31),
#  ('drink', 31),
#  ('better', 31),
#  ('wait', 30),
#  ('super', 29),
#  ('hour', 29),
#  ('people', 29),
#  ('back', 28),
#  ('need', 28),
#  ('wifi', 27),
# ...

# %%
top_20_low = hf.top_twenty(low_df)
top_20_low
# Out:
# [('coffee', 209),
#  ('service', 173),
#  ('starbucks', 129),
#  ('drive', 126),
#  ('get', 118),
#  ('thru', 96),
#  ('location', 94),
#  ('good', 94),
#  ('go', 82),
#  ('great', 80),
#  ('always', 80),
#  ('place', 73),
#  ('order', 64),
#  ('one', 63),
#  ('free', 61),
#  ('slow', 61),
#  ('long', 58),
#  ('staff', 57),
#  ('love', 54),
#  ('donuts', 53)]
